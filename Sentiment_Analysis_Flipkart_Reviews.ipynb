# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:/Users/reddy/OneDrive/Documents/sentiemt/data.csv")

# %%
data
# Out:
#                Reviewer Name               Review Title  \
# 0               Kamal Suresh               Nice product
# 1          Flipkart Customer     Don't waste your money
# 2     A. S. Raja Srinivasan   Did not meet expectations
# 3        Suresh Narayanasamy                       Fair
# 4                  ASHIK P A                Over priced
# ...                      ...                        ...
# 8513                     NaN                        NaN
# 8514                     NaN                        NaN
# 8515                     NaN                        NaN
# 8516                     NaN                        NaN
# 8517                     NaN                        NaN
#
#                   Place of Review  Up Votes  Down Votes   Month  \
# 0      Certified Buyer, Chirakkal     889.0        64.0  Feb-21
# 1      Certified Buyer, Hyderabad     109.0         6.0  Feb-21
# 2     Certified Buyer, Dharmapuri      42.0         3.0  Apr-21
# 3        Certified Buyer, Chennai      25.0         1.0     NaN
# 4                             NaN     147.0        24.0  Apr-16
# ...                           ...       ...         ...     ...
# 8513                          NaN       NaN         NaN     NaN
# 8514                          NaN       NaN         NaN     NaN
# 8515                          NaN       NaN         NaN     NaN
# 8516                          NaN       NaN         NaN     NaN
# 8517                          NaN       NaN         NaN     NaN
#
#                                             Review text  Ratings
# 0     Nice product, good quality, but price is now r...        4
# 1     They didn't supplied Yonex Mavis 350. Outside ...        1
# 2     Worst product. Damaged shuttlecocks packed in ...        1
# 3     Quite O. K. , but nowadays  the quality of the...        3
# 4     Over pricedJust ???620 ..from retailer.I didn'...        1
# ...                                                 ...      ...
# 8513                                                NaN        5
# 8514                                                NaN        2
# 8515                                                NaN        4
# 8516                                                NaN        1
# 8517                                                NaN        4
#
# [8518 rows x 8 columns]

# %%
data.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes   Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb-21
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb-21
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr-21
# 3     Certified Buyer, Chennai      25.0         1.0     NaN
# 4                          NaN     147.0        24.0  Apr-16
#
#                                          Review text  Ratings
# 0  Nice product, good quality, but price is now r...        4
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1
# 2  Worst product. Damaged shuttlecocks packed in ...        1
# 3  Quite O. K. , but nowadays  the quality of the...        3
# 4  Over pricedJust ???620 ..from retailer.I didn'...        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8518 entries, 0 to 8517
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer Name    8508 non-null   object
#  1   Review Title     8508 non-null   object
#  2   Place of Review  8468 non-null   object
#  3   Up Votes         8508 non-null   float64
#  4   Down Votes       8508 non-null   float64
#  5   Month            8053 non-null   object
#  6   Review text      8510 non-null   object
#  7   Ratings          8518 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.5+ KB

# %%
data.describe()
# Out:
#           Up Votes   Down Votes      Ratings
# count  8508.000000  8508.000000  8518.000000
# mean      0.391396     0.121768     4.181028
# std      11.613909     3.248022     1.262200
# min       0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     4.000000
# 50%       0.000000     0.000000     5.000000
# 75%       0.000000     0.000000     5.000000
# max     889.000000   219.000000     5.000000

# %%
data.isnull().sum()
# Out:
# Reviewer Name       10
# Review Title        10
# Place of Review     50
# Up Votes            10
# Down Votes          10
# Month              465
# Review text          8
# Ratings              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 4

# %%
data.drop_duplicates(inplace=True)

# %%
data = data.fillna('Not Specified')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8514 entries, 0 to 8515
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer Name    8514 non-null   object
#  1   Review Title     8514 non-null   object
#  2   Place of Review  8514 non-null   object
#  3   Up Votes         8514 non-null   object
#  4   Down Votes       8514 non-null   object
#  5   Month            8514 non-null   object
#  6   Review text      8514 non-null   object
#  7   Ratings          8514 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 598.6+ KB

# %%
data['Ratings'].unique()
# Out:
# array([4, 1, 3, 5, 2], dtype=int64)

# %%
data[data['Ratings']==3].count()
# Out:
# Reviewer Name      615
# Review Title       615
# Place of Review    615
# Up Votes           615
# Down Votes         615
# Month              615
# Review text        615
# Ratings            615
# dtype: int64

# %%
data=data[data['Ratings']!=3]

# %%
data
# Out:
#                Reviewer Name               Review Title  \
# 0               Kamal Suresh               Nice product
# 1          Flipkart Customer     Don't waste your money
# 2     A. S. Raja Srinivasan   Did not meet expectations
# 4                  ASHIK P A                Over priced
# 5                Baji Sankar      Mind-blowing purchase
# ...                      ...                        ...
# 8509           Not Specified              Not Specified
# 8510           Not Specified              Not Specified
# 8512           Not Specified              Not Specified
# 8513           Not Specified              Not Specified
# 8515           Not Specified              Not Specified
#
#                   Place of Review       Up Votes     Down Votes  \
# 0      Certified Buyer, Chirakkal          889.0           64.0
# 1      Certified Buyer, Hyderabad          109.0            6.0
# 2     Certified Buyer, Dharmapuri           42.0            3.0
# 4                   Not Specified          147.0           24.0
# 5      Certified Buyer, Hyderabad          173.0           45.0
# ...                           ...            ...            ...
# 8509                Not Specified  Not Specified  Not Specified
# 8510                Not Specified  Not Specified  Not Specified
# 8512                Not Specified  Not Specified  Not Specified
# 8513                Not Specified  Not Specified  Not Specified
# 8515                Not Specified  Not Specified  Not Specified
#
#               Month                                        Review text  \
# 0            Feb-21  Nice product, good quality, but price is now r...
# 1            Feb-21  They didn't supplied Yonex Mavis 350. Outside ...
# 2            Apr-21  Worst product. Damaged shuttlecocks packed in ...
# 4            Apr-16  Over pricedJust ???620 ..from retailer.I didn'...
# 5            Oct-18  Good quality product. Delivered on time.READ MORE
# ...             ...                                                ...
# 8509  Not Specified  Not sure why we have charged for this product ...
# 8510  Not Specified                                      Not Specified
# 8512  Not Specified                                      Not Specified
# 8513  Not Specified                                      Not Specified
# 8515  Not Specified                                      Not Specified
#
#       Ratings
# 0           4
# 1           1
# 2           1
# 4           1
# 5           5
# ...       ...
# 8509        1
# 8510        1
# 8512        2
# 8513        5
# 8515        4
#
# [7899 rows x 8 columns]

# %%
sentiment_mapping = {
    1: 'Negative',
    2: 'Negative',
    4: 'Positive',
    5: 'Positive'
}


data['Sentiment'] =data['Ratings'].map(sentiment_mapping)

# %%
data.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 4               ASHIK P A                Over priced
# 5             Baji Sankar      Mind-blowing purchase
#
#                Place of Review Up Votes Down Votes   Month  \
# 0   Certified Buyer, Chirakkal    889.0       64.0  Feb-21
# 1   Certified Buyer, Hyderabad    109.0        6.0  Feb-21
# 2  Certified Buyer, Dharmapuri     42.0        3.0  Apr-21
# 4                Not Specified    147.0       24.0  Apr-16
# 5   Certified Buyer, Hyderabad    173.0       45.0  Oct-18
#
#                                          Review text  Ratings Sentiment
# 0  Nice product, good quality, but price is now r...        4  Positive
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1  Negative
# 2  Worst product. Damaged shuttlecocks packed in ...        1  Negative
# 4  Over pricedJust ???620 ..from retailer.I didn'...        1  Negative
# 5  Good quality product. Delivered on time.READ MORE        5  Positive

# %%
data['Review text'] = data['Review text'].str.replace('READ MORE', '')

# %%
from wordcloud import WordCloud
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from wordcloud import WordCloud
data_positive=data.loc[data["Sentiment"]=="Positive",:]

#joining the positive sentences 
words=" ".join(data_positive["Review text"]).lower()

#cleaned words

cleaned_words=" ".join([word for word in words.split() if word not in ["love","like","great","taste","really","good","best","br"]]) 
positive_wordcloud = WordCloud(stopwords=stopwords.words("english"),
                      background_color='black',
                      width=1600,
                      height=800
                     ).generate(cleaned_words) 
plt.figure(1,figsize=(30,20))
plt.imshow(positive_wordcloud)
plt.axis('off')
plt.show()

# %%
data_negative=data.loc[data["Sentiment"]=="Negative",:]

#joining the positive sentences 
words=" ".join(data_negative["Review text"]).lower()

#cleaned words
cleaned_words=" ".join([word for word in words.split() if word not in ["love","like","great","taste","really","good","best","br"]]) 
negative_wordcloud = WordCloud(stopwords=stopwords.words("english"),
                      background_color='black',
                      width=1600,
                      height=800
                     ).generate(cleaned_words) 
plt.figure(1,figsize=(30,20))
plt.imshow(negative_wordcloud)
plt.axis('off')
plt.show()

# %%
data['Sentiment'] = data['Sentiment'].map({'Positive': 1, 'Negative': 0})

# %% [markdown]
# ## Spliting the data

# %%
X= data[['Review text']]
y = data['Sentiment']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 45)

# %%
lemmatizer=WordNetLemmatizer()

# %% [markdown]
# # Data Cleaning

# %%
# Define preprocess function
def preprocess(raw_text):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", raw_text)
    
    # change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens =nltk.word_tokenize(sentence)
    
      # Lemmatize
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    # remove stop words                
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in lemmatized_tokens if word.lower() not in stop_words]
    
     # Join and return
    return " ".join(filtered_tokens)

# %%
X_train.head()
# Out:
#                                         Review text
# 1761  Thank you so much sir. For solving my problem
# 1460                                       Valuable
# 2023                               Super super nice
# 1790                                   Nice shuttle
# 8181                                       nice one

# %%
from tqdm import tqdm, tqdm_notebook
tqdm.pandas()

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# False

# %%
X_train = X_train['Review text'].progress_apply(lambda x: preprocess(x))
X_test = X_test['Review text'].progress_apply(lambda x: preprocess(x))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5924/5924 [00:02<00:00, 1981.93it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 1975/1975 [00:00<00:00, 3023.08it/s]

# %%
X_train.columns = ["clean_text"]
X_train.head()
# Out:
# 1761    thank much sir solving problem
# 1460                          valuable
# 2023                  super super nice
# 1790                      nice shuttle
# 8181                          nice one
# Name: Review text, dtype: object

# %%
X_test.columns = ["clean_text"]

# %%
X_test.head()
# Out:
# 857                                     good indoor court
# 2572                                              awwssmm
# 3252                                         good product
# 2036    excellent original quality fast delivery even ...
# 7104                        fast delivery thanks flipcart
# Name: Review text, dtype: object

# %%
import mlflow
mlflow.set_experiment("review_sentiment_prediction")
# Out:
# <Experiment: artifact_location='file:///C:/Users/reddy/OneDrive/Documents/sentiemt/mlruns/223360048162329120', creation_time=1711638232092, experiment_id='223360048162329120', last_update_time=1711638232092, lifecycle_stage='active', name='review_sentiment_prediction', tags={}>

# %% [markdown]
# # Running the Experiment

# %%
# import the different classifiers from sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from joblib import Memory

# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Auto Logging All Experiment Runs using MLFlow

# %%
# Define a memory object to cache intermediate results
cachedir = '.cache'
memory = Memory(location=cachedir, verbose=0)



pipelines = {
    'naive_bayes': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', MultinomialNB())
    ], memory=memory),
    'decision_tree': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', DecisionTreeClassifier())
    ], memory=memory),
    'logistic_regression': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', LogisticRegression())
    ], memory=memory)
}
# Define parameter grid for each algorithm
param_grids = {
    'naive_bayes': [
        {
            'vectorization': [CountVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000], 
            'classifier__alpha' : [1, 10]
        }
    ],
    'decision_tree': [
        {
            'vectorization': [CountVectorizer(), TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000],
            'classifier__max_depth': [None, 5, 10]
        }
    ],
    'logistic_regression': [
        {
            'vectorization': [CountVectorizer(), TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000], 
            'classifier__C': [0.1, 1, 10], 
            'classifier__penalty': ['elasticnet'], 
            'classifier__l1_ratio': [0.4, 0.5, 0.6],
            'classifier__solver': ['saga'],
            'classifier__class_weight': ['balanced']
        }
    ]
}

# %%
# Perform GridSearchCV for each algorithm
best_models = {}

for algo in pipelines.keys():
    print("*"*10, algo, "*"*10)
    grid_search = GridSearchCV(estimator=pipelines[algo], 
                               param_grid=param_grids[algo], 
                               cv=5, 
                               scoring='f1', 
                               return_train_score=True,
                               verbose=1
                              )
    mlflow.sklearn.autolog()

    
    with mlflow.start_run() as run:
        # %time grid_search.fit(X_train, y_train)
    
    print('Train Score: ', grid_search.best_score_)
    print('Test Score: ', grid_search.score(X_test, y_test))
    
    best_models[algo] = grid_search.best_estimator_
    print()
# Out:
# ********** naive_bayes **********
# 2024/03/29 15:12:03 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh()
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
#     - warn|w|warning|log|l|1: for a warning message (logged at level CRITICAL, displayed by default)
#     - error|e|exception|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
# 2024/03/29 15:12:03 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# 2024/03/29 15:12:15 INFO mlflow.sklearn.utils: Logging the 5 best runs, 3 runs will be omitted.
# CPU times: total: 6.45 s
# Wall time: 12.5 s
# Train Score:  0.9577799567045892
# Test Score:  0.961704578174489
#
# ********** decision_tree **********
# 2024/03/29 15:12:16 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# 2024/03/29 15:12:45 INFO mlflow.sklearn.utils: Logging the 5 best runs, 19 runs will be omitted.
# CPU times: total: 22.7 s
# Wall time: 29.9 s
# Train Score:  0.9534526243616481
# Test Score:  0.9524617996604414
#
# ********** logistic_regression **********
# 2024/03/29 15:12:46 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# 2024/03/29 15:19:26 INFO mlflow.sklearn.utils: Logging the 5 best runs, 67 runs will be omitted.
# CPU times: total: 6min 32s
# Wall time: 6min 40s
# Train Score:  0.9453615828292123
# Test Score:  0.9490713001797484

# %%
import time
import joblib
import os

# %%
dev = "Shreshta Anugu"
best_models = {}

for algo in pipelines.keys():
    print("*"*10, algo, "*"*10)
    grid_search = GridSearchCV(estimator=pipelines[algo], 
                               param_grid=param_grids[algo], 
                               cv=5, 
                               scoring='f1', 
                               return_train_score=True,
                               verbose=1
                              )
    # Fit
    start_fit_time = time.time()
    grid_search.fit(X_train, y_train)
    end_fit_time = time.time()

    # Predict
    start_predict_time = time.time()
    y_pred = grid_search.predict(X_test)
    end_predict_time = time.time()

    # Saving the best model
    joblib.dump(grid_search.best_estimator_, 'C:/Users/reddy/OneDrive/Documents/sentiemt/best_models/{algo}.pkl')
    model_size = os.path.getsize('C:/Users/reddy/OneDrive/Documents/sentiemt/best_models/{algo}.pkl')

    # Pring Log
    print('Train Score: ', grid_search.best_score_)
    print('Test Score: ', grid_search.score(X_test, y_test))
    print("Fit Time: ", end_fit_time - start_fit_time)
    print("Predict Time: ", end_predict_time - start_predict_time)
    print("Model Size: ", model_size)
    
    print()

    # Start the experiment run
    with mlflow.start_run() as run:
        # Log tags with mlflow.set_tag()
        mlflow.set_tag("developer", dev)

        # Log Parameters with mlflow.log_param()
        mlflow.log_param("algorithm", algo)
        mlflow.log_param("hyperparameter_grid", param_grids[algo])
        mlflow.log_param("best_hyperparameter", grid_search.best_params_)

        # Log Metrics with mlflow.log_metric()
        mlflow.log_metric("train_score", grid_search.best_score_)
        mlflow.log_metric("test_score", grid_search.score(X_test, y_test))
        mlflow.log_metric("fit_time", end_fit_time - start_fit_time)
        mlflow.log_metric("predict_time", end_predict_time - start_predict_time)
        mlflow.log_metric("model_size", model_size)

        # Log Model using mlflow.sklearn.log_model
        mlflow.sklearn.log_model(grid_search.best_estimator_, f"{algo}_model")
# Out:
# 2024/03/29 15:19:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7f2f8935caec4e7db2c7b04fd5e11750', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/03/29 15:19:27 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# ********** naive_bayes **********
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# 2024/03/29 15:19:38 INFO mlflow.sklearn.utils: Logging the 5 best runs, 3 runs will be omitted.
# 2024/03/29 15:19:38 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Train Score:  0.9577799567045892
# Test Score:  0.961704578174489
# Fit Time:  11.692356586456299
# Predict Time:  0.031914710998535156
# Model Size:  99927
# 2024/03/29 15:19:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4098032e36bd4d02b9d80d65dcbbbd57', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/03/29 15:19:43 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# ********** decision_tree **********
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# 2024/03/29 15:20:10 INFO mlflow.sklearn.utils: Logging the 5 best runs, 19 runs will be omitted.
# 2024/03/29 15:20:10 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Train Score:  0.9535793810206157
# Test Score:  0.9532710280373832
# Fit Time:  27.037190437316895
# Predict Time:  0.04288506507873535
# Model Size:  91437
# 2024/03/29 15:20:16 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c8a76e9ae59d4b738eb8d702297796fb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/03/29 15:20:16 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# ********** logistic_regression **********
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# 2024/03/29 15:27:00 INFO mlflow.sklearn.utils: Logging the 5 best runs, 67 runs will be omitted.
# 2024/03/29 15:27:00 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Train Score:  0.9453511400556117
# Test Score:  0.9490713001797484
# Fit Time:  404.77576756477356
# Predict Time:  0.0329127311706543
# Model Size:  64010
